# %%
import pandas as pd
import numpy as np

# %%
filepath = '../data/comptes-administratifs-principaux-ville-departement.csv'#'https://www.data.gouv.fr/fr/datasets/r/5153498f-1337-4d9f-8556-30636aa54231'#
df = pd.read_csv(filepath, sep=";", on_bad_lines='skip')

# %%
df.head()
# Out:
#    exercice_comptable     budget section_budgetaire_i_f sens_depense_recette  \
# 0                2010  M14 Ville         Fonctionnement             Dépenses
# 1                2010  M14 Ville         Fonctionnement             Dépenses
# 2                2010  M14 Ville         Fonctionnement             Dépenses
# 3                2010  M14 Ville         Fonctionnement             Dépenses
# 4                2010  M14 Ville         Fonctionnement             Dépenses
#
#   type_d_operation_r_o_i_m  chapitre_budgetaire_cle  \
# 0                     Réel                       12
# 1                     Réel                       12
# 2                     Réel                       12
# 3                     Réel                       12
# 4                     Réel                       12
#
#      chapitre_niveau_vote_texte_descriptif nature_budgetaire_cle  \
# 0  CHARGES DE PERSONNEL ET FRAIS ASSIMILES                  6451
# ...

# %%
import seaborn as sns

# %%
df.describe()
